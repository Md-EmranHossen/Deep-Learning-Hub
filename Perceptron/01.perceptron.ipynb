# %% [markdown]
# <a href="https://colab.research.google.com/github/Md-EmranHossen/deep-learning-playground/blob/main/Perceptron/01.perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Example

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/Dataset/placement.csv')

# %%
print(df.shape)
df.head()
# Out:
# (100, 3)
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
sns.scatterplot(data=df, x='cgpa', y='resume_score', hue='placed')
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
from sklearn.linear_model import Perceptron
p = Perceptron()

# %%
p.fit(X,y) # Train model
# Out:
# Perceptron()

# %%
p.coef_   # Values of weights
# Out:
# array([[ 40.26, -36.  ]])

# %%
p.intercept_  # Value of bais
# Out:
# array([-25.])

# %%
np.array([-25.])
# Out:
# array([-25.])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X.values,y.values,clf=p,legend=2)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/IRIS.csv')

# %%
print(df.shape)
df.head()
# Out:
# (150, 5)
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
sns.scatterplot(data=df, x='sepal_length', y='sepal_width', hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
from sklearn.linear_model import Perceptron
p = Perceptron()

# %%
p.fit(X,y) # Train model
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[-25.6,  43.5],
#        [ 10.2, -28. ],
#        [ 17.2, -35.2]])

# %%
p.intercept_
# Out:
# array([ 10.,  16., -28.])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-21-5f5d13d93a72> in <cell line: 0>()
#       8
#       9 # Now use y_encoded in the plot_decision_regions function
# ---> 10 plot_decision_regions(X.values, y_encoded, clf=p, legend=2)
#
# /usr/local/lib/python3.11/dist-packages/mlxtend/plotting/decision_regions.py in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, zoom_factor, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, contour_kwargs, scatter_highlight_kwargs, n_jobs)
#     304     )
#     305     cset = ax.contourf(
# --> 306         xx, yy, Z, colors=colors, levels=np.arange(Z.max() + 2) - 0.5, **contourf_kwargs
#     307     )
#     308
#
# /usr/local/lib/python3.11/dist-packages/numpy/core/_methods.py in _amax(a, axis, out, keepdims, initial, where)
#      39 def _amax(a, axis=None, out=None, keepdims=False,
#      40           initial=_NoValue, where=True):
# ---> 41     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#      42
#      43 def _amin(a, axis=None, out=None, keepdims=False,
#
# UFuncTypeError: ufunc 'maximum' did not contain a loop with signature matching types (dtype('<U15'), dtype('<U15')) -> None
